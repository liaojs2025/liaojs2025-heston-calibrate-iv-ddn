# %%
import pandas as pd

# %%
df = pd.read_csv('spy_2020_2022.csv')
df.columns = df.columns.str.strip()
df = df[df['[QUOTE_DATE]'] == ' 2022-09-02']
df.to_csv('spy_2022_09_02.csv', index=False)
# Out:
# /var/folders/r8/fh_rxj4x4m1f6zpb20xvl87r0000gn/T/ipykernel_34791/1223182425.py:1: DtypeWarning: Columns (8,9,10,11,12,13,15,17,18,20,21,23,24,25,26,27,28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('spy_2020_2022.csv')

# %%
df_2 = pd.read_csv('spy_2021_09_01.csv')
df_2['[QUOTE_DATE]'].head(1).item()
# Out:
# ' 2021-09-01'

# %%
df2 = pd.read_csv('spy_2020_2022.csv')
df2.columns = df2.columns.str.strip()
df2 = df2[df2['[QUOTE_DATE]'] == ' 2021-09-02']
df2.to_csv('spy_2021_09_02.csv', index=False)

# %%
df_2['[DTE]'].describe()
# Out:
# count    4965.000000
# mean      149.474691
# std       189.079403
# min         0.000000
# 25%        21.000000
# 50%        79.040000
# 75%       198.000000
# max       835.040000
# Name: [DTE], dtype: float64
